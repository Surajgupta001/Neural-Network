# %% [markdown]
# ## Generating Non-Linear Training Data

# %%
from nnfs.datasets import spiral_data
import matplotlib.pyplot as plt
X, y = spiral_data(samples=100, classes=3)
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="brg")
plt.show()

# %% [markdown]
# The neural network will not be aware of the color differences as the data have no class encoding

# %% [markdown]
# ## What is classes, inheritance and methods in Python?
#
# - **Classes**: In Python, a class is a blueprint for creating objects. It defines a set of attributes and methods that the created objects (instances) will have. Classes allow you to bundle data and functionality together.
#
#   ```python
#   class Dog:
#       def __init__(self, name, age):
#           self.name = name
#           self.age = age
#
#       def bark(self):
#           return f"{self.name} says woof!"
#   ```
#
# - **Inheritance**: Inheritance is a mechanism in Python that allows a new class (called a subclass or derived class) to inherit
# - attributes and methods from an existing class (called a superclass or base class). This promotes code reusability and establishes a hierarchical relationship between classes.
#
#   ```python
#   class Puppy(Dog):
#         def __init__(self, name, age, breed):
#             super().__init__(name, age)  # Call the constructor of the base class
#             self.breed = breed
#
#         def play(self):
#             return f"{self.name} is playing!"
#     ```
# - **Methods**: Methods are functions defined within a class that operate on instances of that class. They can manipulate object data and perform actions related to the object.
#   ```python
#     class Cat:
#         def __init__(self, name):
#             self.name = name
#
#         def meow(self):
#             return f"{self.name} says meow!"
#     ```

# %% [markdown]
# ## Dense Layer Class

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

# %%
# Dense Layer Class
class Layer_Dense:
    # Layer initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        
    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases
        
# Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)

# Perform a forward pass of our training data through this layer
dense1.forward(X)

# Let's see output of the first few samples:
print(dense1.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.0475188e-04  1.1395361e-04 -4.7983500e-05]
#  [-2.7414842e-04  3.1729150e-04 -8.6921798e-05]
#  [-4.2188365e-04  5.2666257e-04 -5.5912682e-05]
#  [-5.7707680e-04  7.1401405e-04 -8.9430439e-05]]
